# %%
#import RegEx or Regular Expression, is a sequence of characters that forms a search pattern. RegEx can be used to check if a string contains the specified search pattern.

import re
import long_responses as long

# %%
#create a function that creates probability that the message is corresponding message

def message_probability(user_message, recognised_words, single_response=False, required_words=[])

# %%
def get_response(user_input):
    split_message = re.split(r'\s+|[,;?!.-]\s*', user_input.lower())
    response = check_all_messages(split_message)
    return response

#above is to split the message into an array
#provide RegEx to remove all the symbols from the messages and allows us just to have the clean words separately so it is much easier to recognize the text
#user_input.lower since python is a case sensitive language

# %%
#Testing the response system
#create an infinite while True loop so we can always get new responses

while True:
    print('Bot: ' + get_response(input('You: ')) )
